# %%
i
# Out:
# hassam

# %%
import pandas as pd
s1 = pd.Series([1,2,3,4,5])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
a = pd.read_csv('business-financial-data-december-2023-quarter-csv.csv')
a.iloc[5:11,2:]
print(a)
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 7390     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 7391     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 7392     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
# 7393     BDCQ.SF8RSCA  2023.09     673.068        NaN      R  Dollars
# 7394     BDCQ.SF8RSCA  2023.12     511.098        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
import pandas as pd
iris = pd.read_csv('business-financial-data-december-2023-quarter-csv.csv')
iris.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
a.describe()
# Out:
#             Period    Data_value  Magnitude  Series_title_5
# count  7395.000000   6736.000000     7395.0             0.0
# mean   2019.708933   4964.577416        6.0             NaN
# std       2.229003   7387.367769        0.0             NaN
# min    2016.060000   -398.194000        6.0             NaN
# 25%    2018.030000    660.517000        6.0             NaN
# 50%    2020.030000   2129.511500        6.0             NaN
# 75%    2022.030000   4672.037750        6.0             NaN
# max    2023.120000  41541.633000        6.0             NaN

# %%
iris.iloc[0:3, 0:2]
# Out:
#   Series_reference   Period
# 0    BDCQ.SF1AA2CA  2016.06
# 1    BDCQ.SF1AA2CA  2016.09
# 2    BDCQ.SF1AA2CA  2016.12

# %%
a.tail()
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 7390     BDCQ.SF8RSCA  2022.12     518.615        NaN      F  Dollars
# 7391     BDCQ.SF8RSCA  2023.03     663.630        NaN      F  Dollars
# 7392     BDCQ.SF8RSCA  2023.06     617.507        NaN      F  Dollars
# 7393     BDCQ.SF8RSCA  2023.09     673.068        NaN      R  Dollars
# 7394     BDCQ.SF8RSCA  2023.12     511.098        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 7390          6  Business Data Collection - BDC
# 7391          6  Business Data Collection - BDC
# 7392          6  Business Data Collection - BDC
# 7393          6  Business Data Collection - BDC
# 7394          6  Business Data Collection - BDC
#
#                                                 Group    Series_title_1  \
# 7390  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 7391  Industry by financial variable (NZSIOC Level 1)  Operating profit
# ...

# %%
a.iloc[4:8,2:]
# Out:
#    Data_value Suppressed STATUS    UNITS  Magnitude  \
# 4    1233.700        NaN      F  Dollars          6
# 5    1282.436        NaN      F  Dollars          6
# 6    1290.820        NaN      F  Dollars          6
# 7    1412.007        NaN      F  Dollars          6
#
#                           Subject  \
# 4  Business Data Collection - BDC
# 5  Business Data Collection - BDC
# 6  Business Data Collection - BDC
# 7  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 4  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 5  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 6  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 7  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
#
#          Series_title_2  Series_title_3 Series_title_4  Series_title_5
# ...

# %%
a.loc[1:10, ("STATUS")]
# Out:
# 1     F
# 2     F
# 3     F
# 4     F
# 5     F
# 6     F
# 7     F
# 8     F
# 9     F
# 10    F
# Name: STATUS, dtype: object

# %%
a.drop('UNITS', axis=1)
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS  Magnitude  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F          6
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F          6
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F          6
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F          6
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F          6
# ...               ...      ...         ...        ...    ...        ...
# 7390     BDCQ.SF8RSCA  2022.12     518.615        NaN      F          6
# 7391     BDCQ.SF8RSCA  2023.03     663.630        NaN      F          6
# 7392     BDCQ.SF8RSCA  2023.06     617.507        NaN      F          6
# 7393     BDCQ.SF8RSCA  2023.09     673.068        NaN      R          6
# 7394     BDCQ.SF8RSCA  2023.12     511.098        NaN      F          6
#
#                              Subject  \
# 0     Business Data Collection - BDC
# ...

# %%
a.head(5)
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
a.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
a.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a.max()
#
# File F:\pythonn\Lib\site-packages\pandas\core\frame.py:11298, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11290 @doc(make_doc("max", ndim=2))
#   11291 def max(
#   11292     self,
#    (...)
#   11296     **kwargs,
#   11297 ):
# > 11298     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11299     if isinstance(result, Series):
#   11300         result = result.__finalize__(self, method="max")
#
# File F:\pythonn\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11969 def max(
#   11970     self,
#   11971     axis: Axis | None = 0,
#    (...)
#   11974     **kwargs,
#   11975 ):
# > 11976     return self._stat_function(
#   11977         "max",
#   11978         nanops.nanmax,
# ...

# %%
a.min(Data_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a.min(Data_value)
#
# NameError: name 'Data_value' is not defined

# %%
a.median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File F:\pythonn\Lib\site-packages\pandas\core\nanops.py:785, in nanmedian(values, axis, skipna, mask)
#     784 try:
# --> 785     values = values.astype("f8")
#     786 except ValueError as err:
#     787     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'BDCQ.SF1AA2CA'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a.median()
#
# File F:\pythonn\Lib\site-packages\pandas\core\frame.py:11348, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11340 @doc(make_doc("median", ndim=2))
#   11341 def median(
#   11342     self,
#    (...)
#   11346     **kwargs,
#   11347 ):
# ...

# %%
a.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
a['STATUS'].value_counts()
# Out:
# STATUS
# F    4935
# R    1801
# C     659
# Name: count, dtype: int64

# %%
a.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from matplotlib import pyplot as plt
x = np.arange(1,11)
x

# %%
y= 3*x
y
# Out:
# array([ 3,  6,  9, 12, 15, 18, 21, 24, 27, 30])

# %%
s.plot(x,y, color = 'r', linestyle = ':', linewidth = 5)
s.title("Line plot")
s.xlabel("x axis")
s.ylabel("y axis")
s.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s.plot(x,y, color = 'r', linestyle = ':', linewidth = 5)
#       2 s.title("Line plot")
#       3 s.xlabel("x axis")
#
# NameError: name 's' is not defined

# %%
x1 = 2*x
y1 = 3*y

# %%
a = [20,40, 60]
x= [12,20,30]
y = [5,10,15]
plt.scatter(a,x, marker = "*", c = "r")
plt.scatter(a,y, c = "g")
plt.show()

# %%
student = { 'hassam':  22, 'minhaj' : 18, 'khizer': 17 , 'areeb' : 16}
names = list(student.keys())
value = list(student.values())
plt.barh(names, value, color = 'g')
plt.grid(True)
plt.show()

# %%
a = [20,40, 60]
x= [12,20,30]
y = [5,10,15]

plt.subplot(1,2,1)
plt.scatter(a,x, marker = "*", c = "r")
plt.subplot(1,2,2)
plt.scatter(a,y, c = "g")
plt.show()

# %%
data = [6,4,3,2,2,1]
plt.hist(data, color = 'r')
plt.show()

# %%
iris = pd.read_csv("business-financial-data-december-2023-quarter-csv.csv")
iris.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
plt.hist(iris['Data_value'],color = 'g')
plt.show()

# %%
iris.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
one = [1,2,4,4,5,5,3,2,5,5]
two = [7,6,5,6,7,8,9,4,3,2,5]
three = [6,5,4,3,2,1,1,3,54,6,9]
data = list([one,two,three])
plt.boxplot(data)
plt.show()

# %%
a = [1,2,3]
b = [4,5,6]
c= [7,8,9]
data=list([a,b,c])
plt.violinplot(data)
plt.show()

# %%
names = ['hassam', 'minhaj' , 'areeb', 'khizer']
runs  = [25,6,10, 16]
plt.pie(runs, labels =names)
plt.show()

# %%
names = ['hassam', 'minhaj', 'areeb', 'khizer']
runs = [26, 18, 3, 11]

plt.pie(runs, labels=names, autopct='%0.1f%%', colors=['yellow', 'red', 'pink', 'blue'])
plt.show()

# %%
names = ['hassam', 'minhaj', 'areeb', 'khizer']
runs = [26, 18, 3, 11]

plt.pie(runs, labels=names, autopct='%0.1f%%', colors=['yellow', 'red', 'pink', 'blue'], radius = 2)
plt.pie([1], colors = ['w'], radius = 1)
plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# Load an example dataset from Seaborn
df = sns.load_dataset('tips')
df.head()

# %%
df.shape
# Out:
# (244, 7)

# %%
sns.lineplot(x='total_bill', y = 'tip', data = df, markers = True)
plt.show()

# %%
sns.lineplot(x='total_bill', y = 'tip', data = df, hue = 'sex')
plt.show()

# %%
sns.lineplot(x='total_bill', y = 'tip', data = df, hue = 'sex' , style = 'smoker', markers  = True)
plt.show()

# %%
import pandas as pd

# %%
p = pd.read_csv("business-price-indexes-december-2023-quarter-csv.csv")
p.head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8060\1773446076.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   p = pd.read_csv("business-price-indexes-december-2023-quarter-csv.csv")
#   Series_reference   Period  Data_value STATUS  UNITS  \
# 0        CEPQ.S611  1989.12  456.670842  FINAL  Index
# 1        CEPQ.S611  1990.03  458.954197  FINAL  Index
# 2        CEPQ.S611  1990.06  466.717601  FINAL  Index
# 3        CEPQ.S611  1990.09  462.607563  FINAL  Index
# 4        CEPQ.S611  1990.12  467.174272  FINAL  Index
#
#                            Subject  \
# 0  Capital Goods Price Index - CEP
# 1  Capital Goods Price Index - CEP
# 2  Capital Goods Price Index - CEP
# 3  Capital Goods Price Index - CEP
# 4  Capital Goods Price Index - CEP
#
#                                                Group Series_title_1  \
# 0  Price Index all groups of capital goods (Base:...     All Groups
# ...

# %%
sns.barplot(x = "Data_value", y = 'Period', data = p)
plt.show()

# %%
print("a")

# %%
sns.barplot(x = "period", y = "Data_value", data= p, color = 'orange')
plt.show()
