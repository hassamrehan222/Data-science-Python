# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv("players_20.csv")
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object', name='nationality')

# %%
plt.figure(figsize = (5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]), color = "b")
plt.show()

# %%
player_sal = fifa[['short_name', 'age']]
player_sal.head()
# Out:
#           short_name  age
# 0           L. Messi   32
# 1  Cristiano Ronaldo   34
# 2          Neymar Jr   27
# 3           J. Oblak   26
# 4          E. Hazard   28

# %%
player_sal = player_sal.sort_values(by=['age'], ascending = False)
player_sal.head()
# Out:
#          short_name  age
# 13003  H. Sulaimani   42
# 11832      C. Muñoz   42
# 200       G. Buffon   41
# 3706   C. Lucchetti   41
# 10665      F. Kippe   41

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_sal['short_name'])[0:5], list(player_sal['age'])[0:5],color = ["blue", "green", "pink", "red", "black"])
plt.show()

# %%
# Out:
#          short_name  age
# 13003  H. Sulaimani   42
# 11832      C. Muñoz   42
# 200       G. Buffon   41
# 3706   C. Lucchetti   41
# 10665      F. Kippe   41

# %%
player_shot = fifa[['short_name', 'shooting']]

# %%
player_shot.sort_values(by=['shooting'], ascending = False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
real_mad = fifa[fifa['club'] == 'Real Madrid']

# %%
real_mad.sort_values(by=['age'], ascending  =  False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 8       177003  https://sofifa.com/player/177003/luka-modric/2...
# 53      193041  https://sofifa.com/player/193041/keylor-navas/...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 101     176676  https://sofifa.com/player/176676/marcelo-vieir...
#
#        short_name                       long_name  age         dob  height_cm  \
# 18   Sergio Ramos             Sergio Ramos García   33  1986-03-30        184
# 8       L. Modrić                     Luka Modrić   33  1985-09-09        172
# 53       K. Navas                    Keylor Navas   32  1986-12-15        185
# 46     K. Benzema                   Karim Benzema   31  1987-12-19        185
# 101       Marcelo  Marcelo Vieira da Silva Júnior   31  1988-05-12        174
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...
